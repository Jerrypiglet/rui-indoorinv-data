# %%
import os
from enum import Enum
from typing import Any, Dict, Optional
from typing_extensions import Literal
from pathlib import Path
import matplotlib.pyplot as plt
from joblib import Parallel, delayed  
from tqdm.notebook import tqdm 
import cv2
import numpy as np
import shutil
import subprocess
import tempfile
os.environ["OPENCV_IO_ENABLE_OPENEXR"]="1"

import imageio
import rawpy
from scipy import ndimage
import lensfunpy

import nerfstudio
from nerfstudio.process_data import colmap_utils
from nerfstudio.process_data import colmap_utils, hloc_utils
from nerfstudio.utils.io import load_from_json, write_to_json
from nerfstudio.data.utils.colmap_parsing_utils import (
    read_cameras_binary, read_images_binary, qvec2rotmat, 
)
    
from nerfstudio.process_data.colmap_utils import parse_colmap_camera_params

# %%
def get_files(path):
    path = Path(path)
    files = []
    for p in sorted(os.listdir(path)):
        p = path / p
        if p.is_file():
            files.append(p)
    return files

root_dir = Path("/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen")
calib_dir = root_dir.parent / "calib_raw"
image_dir = root_dir / "raw_images"

calib_paths = get_files(calib_dir)
# hdr_calib_paths = get_files(hdr_calib_dir)
image_paths = get_files(image_dir)

# %%
# TestCapture (Canon)
times = np.array([1/32, 1/16, 1/8, 1/4, 1/2], dtype=np.float32)
# times = np.array([1/30, 1/15, 1/8, 1/4, 1/2], dtype=np.float32)

# # Dormroom
# times = np.array([1/32, 1/256, 1/4, 1/2048, 2], dtype=np.float32)

# # KitchenV1-V2
# times = np.array([1/12, 1/24, 1/6, 1/48, 1/3], dtype=np.float32)
# KitchenV3
# times = np.array([1/8, 1/16, 1/4, 1/32, 1/2], dtype=np.float32)

# # Conference Room
# times = np.array([1/15, 1/30, 1/8, 1/60, 1/4, 1/125, 1/2, 1/250, 1], dtype=np.float32)

# %%
# index = 77 * len(times)+4
index = 4
p = image_paths[index]
img_max = 2**14 - 1

with rawpy.imread(str(p)) as raw:
    raw_processed = cv2.demosaicing(raw.raw_image, code=cv2.COLOR_BAYER_BG2BGR)
    
height, width, _ = raw_processed.shape

db = lensfunpy.Database()
# cam = db.find_cameras("Sony", "ILCE-7M3")[0]
# lens = db.find_lenses(cam, "Sony", "FE 24-105mm")[0]
cam = db.find_cameras("Canon", "Canon EOS 5D Mark III")[0]
lens = db.find_lenses(cam, "Canon", "Canon EF 24-70mm f/2.8L II USM")[0]

mod = lensfunpy.Modifier(lens, cam.crop_factor, width, height)
# Sony Setting
# focal_length, aperture, distance = 24, 20, 0.5
# Canon Setting
focal_length, aperture, distance = 24, 19, 2.2
mod.initialize(focal_length, aperture, distance, scale=1.0, pixel_format=np.float32)

def read_process_img(
    p,
    mod=mod,
    crop_x=150,
    crop_y=100,
    img_max=np.float32(2**14-1),
):
    # Images should be linear rgb for tiff(float) images
    # https://lensfun.github.io/calibration-tutorial/lens-vignetting.html
    with rawpy.imread(str(p)) as raw:
        image = raw.raw_image.copy()
        black = np.reshape(np.array(raw.black_level_per_channel, dtype=image.dtype), (2, 2))
        black = np.tile(black, (image.shape[0]//2, image.shape[1]//2))
        image = np.maximum(image, black) - black
        image = cv2.demosaicing(image, code=cv2.COLOR_BAYER_BG2BGR)
        image = image / (raw.white_level - black)[...,np.newaxis].astype(np.float32)
    did_apply = mod.apply_color_modification(image)
    image = np.clip(image, 0, 1)
    H, W = image.shape[:2]
    print(image.shape, image[crop_y:H-crop_y, crop_x:W-crop_x].shape)

    return image[crop_y:H-crop_y, crop_x:W-crop_x]

# img = read_process_img(image_paths[index])
# wb_patch = img[2350:2400, 2490:2540]
# fig = plt.figure(figsize=(4,4))
# plt.imshow((wb_patch * 2.5)[...,[2,1,0]])
# white_balance = np.mean(wb_patch, axis=(0,1))
# white_balance = white_balance[1] / white_balance
white_balance = np.array([2.5430965, 1., 1.5503172], dtype=np.float32)
# fig = plt.figure(figsize=(8,6))
# plt.imshow((img * white_balance * 1.5)[...,[2,1,0]])

# %%
# # images = []
# # for i in tqdm(range(5)):
# #     images.append(read_process_img(str(image_paths[i])))

# # times = np.array([1/32, 1/16, 1/8, 1/4, 1/2], dtype=np.float32)
# # times = np.array([1/30, 1/15, 1/8, 1/4, 1/2], dtype=np.float32)
# avg = []
# for image, time in zip(images, times):
#     img_patch = image[2350:2400, 2490:2540]
#     avg.append(np.average(img_patch, axis=(0,1)) / time * 2)
# avg = np.array(avg)
# print("Mean:", np.mean(avg, axis=0), "Std:", np.std(avg, axis=0))

# %%
# downsample images, resolution is too high
downsample_scale = 8
checkerboard_size = (16, 13)
# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 500, 0.001)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((np.prod(checkerboard_size),3), np.float32)
objp[:,:2] = np.mgrid[0:checkerboard_size[0],0:checkerboard_size[1]].T.reshape(-1,2)
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.
# Main loop for extracting corners
for calib_img_path in tqdm(calib_paths):
    img = read_process_img(calib_img_path) * white_balance
    # Linear to grayscale conversion with scaling
    img_gray = img[...,2] * 0.2126 + img[...,1] * 0.7152 + img[...,0] * 0.0722
#     img_gray = np.average(img, axis=-1)
    img_gray /= np.max(img_gray)
    img_gray_resized = cv2.resize(
        img_gray, 
        dsize=(img.shape[1] // downsample_scale, img.shape[0] // downsample_scale), 
        interpolation=cv2.INTER_AREA)
    ret, corners_resized = cv2.findChessboardCorners(
        (img_gray_resized * 255).astype(np.uint8), checkerboard_size, None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        corners = corners_resized * downsample_scale
        objpoints.append(objp)
        corners2 = cv2.cornerSubPix(img_gray, np.floor(corners), (40,40), (-1,-1), criteria)
        imgpoints.append(corners2)
        
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_gray.shape[::-1], None, None)
print("Reprojection error:", ret)

# fig = plt.figure(figsize=(8,6))
# plt.imshow(img_gray)
# plt.plot(corners2[:,0,0], corners2[:,0,1], "ro")
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# Reprojection error: 0.5233185545509426

# %%
h,  w = img_gray.shape[:2]
exr_resize_shape = (768, 512)
upsample_factor = int(np.max(np.ceil(img_gray.shape[-1::-1] / np.array(exr_resize_shape))))

w_new, h_new = np.array(exr_resize_shape) * upsample_factor
newcameramtx, roi = cv2.getOptimalNewCameraMatrix(
    mtx, dist, (w,h), 
    0, # Contain only the valid pixels
    (w_new,h_new)
)
mapx, mapy = cv2.initUndistortRectifyMap(mtx, dist, None, newcameramtx, (w_new,h_new), cv2.CV_32F)

# %%
# img = read_process_img(str(image_paths[269])) * 2
# img = cv2.undistort(img, mtx, dist, None, newcameramtx)
# imageHDR = img * white_balance

# fig = plt.figure(figsize=(8,6))
# plt.imshow(imageHDR[...,[2,1,0]])

# %%
# Create directories
exr_output_dir = root_dir / "merged_images"
exr_output_dir.mkdir(exist_ok=True)
png_output_dir = root_dir / "png_images"
png_output_dir.mkdir(exist_ok=True)
pose_output_dir = root_dir / "pose_images"
pose_output_dir.mkdir(exist_ok=True)
# Setup the image scales and output brightness
pose_resize_scale = 4
png_exposure_scale = 1.5
# Setup the params for combining images
apply_median_blur = False
times_min_index = np.argmin(times)
times_max_index = np.argmax(times)
exposure_target = times[-1]

# %%
import subprocess
import multiprocessing
from multiprocessing import Pool
import time

def process_bracket(index):
    exr_path = exr_output_dir / f"img_{str(index).zfill(4)}.exr"
    pose_path = pose_output_dir / f"img_{str(index).zfill(4)}.png"
    png_path = png_output_dir / f"img_{str(index).zfill(4)}.png"
    # Get the correct image index
#     index *= len(times)
    index_ = index * len(times)
    
    # Read and correct images
    image_list = []
    for i, time in enumerate(times):
        image_list.append(image_paths[index_])
    print('-- Working on index: %d'%index)
#     print([Path(_).stem for _ in image_list])

    images = []
    for i, time in enumerate(times):
        images.append(read_process_img(str(image_paths[index_]), crop_x=150, crop_y=100))
        index_ += 1
    images = np.array(images)

    
    # Calculate hat function for averaging the values
    weights = np.minimum(images, 1.0 - images)
    weights[times_max_index][images[times_max_index]<0.5] = 1.0
    weights[times_min_index][images[times_min_index]>0.5] = 1.0
    weights /= np.sum(weights, axis=0)
    
    # Scale the images to same exposure
    images_scaled = images * (exposure_target / times)[:, np.newaxis, np.newaxis, np.newaxis]
    # Combine the images
    imageHDR = np.sum(images_scaled * weights, axis=0) * white_balance
    if apply_median_blur:
        imageHDR = cv2.medianBlur(imageHDR, ksize=3)
        
    # Undistort hdr image
    imageHDR = cv2.remap(imageHDR, mapx, mapy, cv2.INTER_LINEAR)
    
    # Write exr image for reconstruction
    output_img_resized = cv2.resize(
        imageHDR, 
        dsize=exr_resize_shape, 
        interpolation=cv2.INTER_AREA)
    cv2.imwrite(str(exr_path), output_img_resized)
    print('EXR dumped to' + str(exr_path))
    png_image = np.clip(output_img_resized * png_exposure_scale, a_min=0, a_max=1) **(1/2.2)
    png_image = (png_image * 255).astype(np.uint8)
    cv2.imwrite(str(png_path), png_image)
    
    # Write png pose image for colmap poses
    pose_image = cv2.resize(
        imageHDR, 
        dsize=(exr_resize_shape[0]*pose_resize_scale, exr_resize_shape[1]*pose_resize_scale), 
        interpolation=cv2.INTER_AREA)
    pose_image = np.clip(pose_image * png_exposure_scale, a_min=0, a_max=1) **(1/2.2)
    pose_image = (pose_image * 255).astype(np.uint8)
    cv2.imwrite(str(pose_path), pose_image)
    
tic = time.time()
p = Pool(processes=8)
index_list = range(len(image_paths)//len(times))
list(tqdm(p.imap_unordered(process_bracket, index_list), total=len(index_list)))
p.close()
p.join()
print('==== ...DONE. Took %.2f seconds'%(time.time() - tic))
# Out:
# -- Working on index: 0
#   0%|          | 0/187 [00:00<?, ?it/s]
# -- Working on index: 1-- Working on index: 2-- Working on index: 3-- Working on index: 7-- Working on index: 4-- Working on index: 5-- Working on index: 6
#
#
#
#
#
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3950, 5920, 3)(3750, 5620, 3)
# (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)(3950, 5920, 3)
#  (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)(3950, 5920, 3)
#  (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0006.exr
# -- Working on index: 8
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0007.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0001.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0002.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0000.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0004.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0005.exr
# -- Working on index: 9
# -- Working on index: 10
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0003.exr
# -- Working on index: 11
# -- Working on index: 12
# -- Working on index: 13
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 14
# -- Working on index: 15
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0009.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0010.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0008.exr
# -- Working on index: 16
# -- Working on index: 17
# -- Working on index: 18
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0015.exrEXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0012.exr
#
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0011.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0014.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0013.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 19
# -- Working on index: 20
# -- Working on index: 21
# (3950, 5920, 3)-- Working on index: 22 (3750, 5620, 3)
#
# -- Working on index: 23
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0016.exr
# -- Working on index: 24
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0017.exr
# -- Working on index: 25
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0018.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0022.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0020.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0019.exr
# -- Working on index: 26
# -- Working on index: 27
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0023.exr
# -- Working on index: 28
# -- Working on index: 29
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0021.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 30
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 31
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0024.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 32
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0025.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 33
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0027.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 34
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0029.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0028.exr
# -- Working on index: 35
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0031.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0026.exr
# -- Working on index: 36
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0030.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 37
# -- Working on index: 38
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 39
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0032.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 40
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0033.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 41
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0034.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 42
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0035.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0036.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 43
# -- Working on index: 44
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0038.exr
# -- Working on index: 45
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0037.exr
# -- Working on index: 46
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0039.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0040.exr
# -- Working on index: 47
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0041.exr
# -- Working on index: 48
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 49
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0042.exr
# (3950, 5920, 3) (3750, 5620, 3)(3950, 5920, 3)
#  (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 50
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0043.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0044.exr
# (3950, 5920, 3) (3950, 5920, 3)(3750, 5620, 3)
# (3750, 5620, 3)
# -- Working on index: 51
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 52
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0045.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 53
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0048.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0049.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0046.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0047.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0050.exr
# -- Working on index: 54
# -- Working on index: 55
# -- Working on index: 56
# -- Working on index: 57
# -- Working on index: 58
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0051.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0052.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 59
# -- Working on index: 60
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0053.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 61
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0055.exr
# -- Working on index: 62
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0054.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0056.exr
# -- Working on index: 63
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0058.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0057.exr
# -- Working on index: 64
# -- Working on index: 65
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 66
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0060.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0059.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 67
# -- Working on index: 68
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0061.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 69
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)(3950, 5920, 3)  (3750, 5620, 3)(3750, 5620, 3)
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0062.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 70
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0063.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)(3950, 5920, 3)  (3750, 5620, 3)(3750, 5620, 3)
#
# -- Working on index: 71
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0064.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0065.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 72
# -- Working on index: 73
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0066.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 74
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0068.exrEXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0069.exr
#
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0067.exr
# -- Working on index: 75-- Working on index: 76
#
# -- Working on index: 77
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0070.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 78
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0073.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0071.exr
# -- Working on index: 79
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 80
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0072.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 81
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0074.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 82
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0076.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0075.exr
# -- Working on index: 83
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0077.exr
# -- Working on index: 84
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 85
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0078.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 86
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0079.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0080.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 87
# -- Working on index: 88
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0081.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 89
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0082.exr
# -- Working on index: 90
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0083.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0084.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 91
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0085.exr
# -- Working on index: 92
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0086.exr
# -- Working on index: 93
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 94
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0087.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0088.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 95
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 96(3950, 5920, 3)
# (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0089.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 97
# (3950, 5920, 3)(3950, 5920, 3)  (3750, 5620, 3)(3750, 5620, 3)
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0091.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0092.exr
# -- Working on index: 98
# -- Working on index: 99
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0094.exrEXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0090.exr
#
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0093.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0095.exr
# -- Working on index: 100
# -- Working on index: 101
# -- Working on index: 102
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0096.exr
# -- Working on index: 103
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 104
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0097.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 105
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0098.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 106
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0099.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 107
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0100.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0104.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0103.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 108
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0101.exr
# -- Working on index: 109
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0102.exr-- Working on index: 110
#
# -- Working on index: 111
# -- Working on index: 112
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0105.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 113
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3950, 5920, 3) (3750, 5620, 3)
# (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0106.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 114
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0107.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 115
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)(3950, 5920, 3)
# (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0108.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 116
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0109.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0110.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 117
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)-- Working on index: 118
# (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0111.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0112.exr
# -- Working on index: 119
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 120
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0113.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 121
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0114.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 122
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0115.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 123
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0116.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 124
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0117.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0118.exr
# -- Working on index: 125
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 126
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0120.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0119.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0121.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0122.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0123.exr
# -- Working on index: 127
# -- Working on index: 128
# -- Working on index: 129
# -- Working on index: 130
# -- Working on index: 131
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0124.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 132
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0125.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0126.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 133
# -- Working on index: 134
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0128.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 135
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0127.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0131.exr
# -- Working on index: 136
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 137
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0129.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0130.exr
# -- Working on index: 138
# -- Working on index: 139
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0132.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 140
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0133.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0134.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 141
# -- Working on index: 142
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0135.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 143
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0137.exr
# -- Working on index: 144
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0138.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 145
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0136.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0140.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0139.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0141.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0142.exr
# -- Working on index: 146
# -- Working on index: 147
# -- Working on index: 148
# -- Working on index: 149-- Working on index: 150
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0143.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)-- Working on index: 151
# (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0144.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 152
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)(3750, 5620, 3)
# (3950, 5920, 3)(3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0145.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 153
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0149.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0147.exr
# -- Working on index: 154
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0150.exr
# -- Working on index: 155
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0148.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0146.exr
# -- Working on index: 156
# -- Working on index: 157
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 158
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0151.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 159
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0152.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 160
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0154.exr
# -- Working on index: 161
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0153.exr
# -- Working on index: 162
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0155.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0156.exr
# -- Working on index: 163
# -- Working on index: 164
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0157.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0159.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0158.exr
# -- Working on index: 165
# (3950, 5920, 3) EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0160.exr(3750, 5620, 3)
#
# -- Working on index: 166
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 167
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 168
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0161.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 169
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0162.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0164.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0163.exr
# -- Working on index: 170
# -- Working on index: 171
# -- Working on index: 172
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0166.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0165.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0168.exr
# -- Working on index: 173
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 174
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0167.exr
# -- Working on index: 175
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 176
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0169.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 177
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)(3950, 5920, 3)  (3750, 5620, 3)(3750, 5620, 3)
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0171.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 178
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0170.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0172.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 179
# -- Working on index: 180
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0173.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0175.exr
# -- Working on index: 181
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0174.exr
# -- Working on index: 182
# -- Working on index: 183
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0176.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0177.exr
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 184
# (3950, 5920, 3) (3750, 5620, 3)
# -- Working on index: 185
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3)(3950, 5920, 3)  (3750, 5620, 3)(3750, 5620, 3)
#
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0178.exr
# -- Working on index: 186
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0180.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0179.exr
# (3950, 5920, 3) (3750, 5620, 3)
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0181.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0182.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0185.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0183.exr
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0184.exr
# (3950, 5920, 3) (3750, 5620, 3)
# EXR dumped to/Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/merged_images/img_0186.exr
# ==== ...DONE. Took 350.21 seconds

# %% [markdown]
# ## Colmap reconstruction

# %%
from nerfstudio.process_data.colmap_utils import get_colmap_version, get_vocab_tree
from nerfstudio.utils.rich_utils import status
from nerfstudio.utils.scripts import run_command
from rich.console import Console
CONSOLE = Console(width=120)

# %%
class CameraModel(Enum):
    """Enum for camera types."""

    OPENCV = "OPENCV"
    OPENCV_FISHEYE = "OPENCV_FISHEYE"
    PINHOLE = "PINHOLE"
    SIMPLE_PINHOLE = "SIMPLE_PINHOLE"


def run_colmap(
    image_dir: Path,
    colmap_dir: Path,
    camera_model: CameraModel,
    camera_mask_path: Optional[Path] = None,
    camera_params = None,
    gpu: bool = True,
    verbose: bool = False,
    matching_method: Literal["vocab_tree", "exhaustive", "sequential"] = "vocab_tree",
    colmap_cmd: str = "colmap",
):
    camera_params = '"' + ",".join([i.astype(str) for i in camera_params]) + '"'
    colmap_version = get_colmap_version(colmap_cmd)

    colmap_database_path = colmap_dir / "database.db"
    if colmap_database_path.exists():
        # Can't use missing_ok argument because of Python 3.7 compatibility.
        colmap_database_path.unlink()

    # Feature extraction
    feature_extractor_cmd = [
        f"{colmap_cmd} feature_extractor",
        f"--database_path {colmap_dir / 'database.db'}",
        f"--image_path {image_dir}",
        "--ImageReader.single_camera 1",
        f"--ImageReader.camera_model {camera_model.value}",
        f"--ImageReader.camera_params {camera_params}",
        f"--SiftExtraction.use_gpu {int(gpu)}",
    ]
    if camera_mask_path is not None:
        feature_extractor_cmd.append(f"--ImageReader.camera_mask_path {camera_mask_path}")
    feature_extractor_cmd = " ".join(feature_extractor_cmd)
    with status(msg="[bold yellow]Running COLMAP feature extractor...", spinner="moon", verbose=verbose):
        run_command(feature_extractor_cmd, verbose=verbose)

    CONSOLE.log("[bold green]:tada: Done extracting COLMAP features.")

    # Feature matching
    feature_matcher_cmd = [
        f"{colmap_cmd} {matching_method}_matcher",
        f"--database_path {colmap_dir / 'database.db'}",
        f"--SiftMatching.use_gpu {int(gpu)}",
    ]
    if matching_method == "vocab_tree":
        vocab_tree_filename = get_vocab_tree()
        feature_matcher_cmd.append(f"--VocabTreeMatching.vocab_tree_path {vocab_tree_filename}")
    feature_matcher_cmd = " ".join(feature_matcher_cmd)
    with status(msg="[bold yellow]Running COLMAP feature matcher...", spinner="runner", verbose=verbose):
        run_command(feature_matcher_cmd, verbose=verbose)
    CONSOLE.log("[bold green]:tada: Done matching COLMAP features.")

    # Bundle adjustment
    sparse_dir = colmap_dir / "sparse"
    sparse_dir.mkdir(parents=True, exist_ok=True)
    mapper_cmd = [
        f"{colmap_cmd} mapper",
        f"--database_path {colmap_dir / 'database.db'}",
        f"--image_path {image_dir}",
        f"--output_path {sparse_dir}",
        "--Mapper.ba_refine_focal_length 0",
        "--Mapper.ba_refine_extra_params 0",
    ]
    if colmap_version >= 3.7:
        mapper_cmd.append("--Mapper.ba_global_function_tolerance 1e-6")

    mapper_cmd = " ".join(mapper_cmd)

    with status(
        msg="[bold yellow]Running COLMAP bundle adjustment... (This may take a while)",
        spinner="circle",
        verbose=verbose,
    ):
        run_command(mapper_cmd, verbose=verbose)
    CONSOLE.log("[bold green]:tada: Done COLMAP bundle adjustment.")
    with status(msg="[bold yellow]Refine intrinsics...", spinner="dqpb", verbose=verbose):
        bundle_adjuster_cmd = [
            f"{colmap_cmd} bundle_adjuster",
            f"--input_path {sparse_dir}/0",
            f"--output_path {sparse_dir}/0",
            "--BundleAdjustment.refine_principal_point 0",
            "--BundleAdjustment.refine_focal_length 0",
            "--BundleAdjustment.refine_extra_params 0",
        ]
        run_command(" ".join(bundle_adjuster_cmd), verbose=verbose)
    CONSOLE.log("[bold green]:tada: Done refining intrinsics.")

# %%
from hloc import (
    extract_features,
    match_features,
    pairs_from_exhaustive,
    pairs_from_retrieval,
    reconstruction,
)
import pycolmap

def run_hloc(
    image_dir: Path,
    colmap_dir: Path,
    camera_model: CameraModel,
    camera_params = None,
    verbose: bool = False,
    matching_method: Literal["vocab_tree", "exhaustive", "sequential"] = "vocab_tree",
    feature_type: Literal[
        "sift", "superpoint_aachen", "superpoint_max", "superpoint_inloc", "r2d2", "d2net-ss", "sosnet", "disk"
    ] = "superpoint_aachen",
    matcher_type: Literal[
        "superglue", "superglue-fast", "NN-superpoint", "NN-ratio", "NN-mutual", "adalam"
    ] = "superglue",
    num_matched: int = 50,
) -> None:
    camera_params = ",".join([i.astype(str) for i in camera_params])
    
    outputs = colmap_dir
    sfm_pairs = outputs / "pairs-netvlad.txt"
    sfm_dir = outputs / "sparse" / "0"
    features = outputs / "features.h5"
    matches = outputs / "matches.h5"

    retrieval_conf = extract_features.confs["netvlad"]
    feature_conf = extract_features.confs[feature_type]
    matcher_conf = match_features.confs[matcher_type]

    references = [p.relative_to(image_dir).as_posix() for p in image_dir.iterdir()]
    extract_features.main(feature_conf, image_dir, image_list=references, feature_path=features)
    if matching_method == "exhaustive":
        pairs_from_exhaustive.main(sfm_pairs, image_list=references)
    else:
        retrieval_path = extract_features.main(retrieval_conf, image_dir, outputs)
        if num_matched >= len(references):
            num_matched = len(references)
        pairs_from_retrieval.main(retrieval_path, sfm_pairs, num_matched=num_matched)
    match_features.main(matcher_conf, sfm_pairs, features=features, matches=matches)

    image_options = pycolmap.ImageReaderOptions(  # pylint: disable=c-extension-no-member
        camera_model=camera_model.value,
        camera_params=camera_params
    )
    min_match_score = None
    skip_geometric_verification = False
    
    sfm_dir.mkdir(parents=True, exist_ok=True)
    database = sfm_dir / 'database.db'
    
    reconstruction.create_empty_db(database)
    reconstruction.import_images(
        image_dir, database, pycolmap.CameraMode.SINGLE, references, image_options)
    image_ids = reconstruction.get_image_ids(database)
    reconstruction.import_features(image_ids, database, features)
    reconstruction.import_matches(image_ids, database, sfm_pairs, matches,
                   min_match_score, skip_geometric_verification)
    
    mapper_options = {
      "ba_refine_focal_length": False,
      "ba_refine_principal_point": False,
      "ba_refine_extra_params": False,
    }
    
    if not skip_geometric_verification:
        reconstruction.estimation_and_geometric_verification(
            database, sfm_pairs, verbose)
    rec_out = reconstruction.run_reconstruction(
        sfm_dir, database, image_dir, verbose, mapper_options)
    if rec_out is not None:
#         logger.info(f'Reconstruction statistics:\n{rec_out.summary()}'
#                     + f'\n\tnum_input_images = {len(image_ids)}')
        print(f'Reconstruction statistics:\n{rec_out.summary()}'
                    + f'\n\tnum_input_images = {len(image_ids)}')

# %%
# image_dir=pose_output_dir
# colmap_dir=colmap_dir
# camera_model=camera_model
# verbose=True
# matching_method="exhaustive"
# feature_type="superpoint_inloc"
# matcher_type="superglue"

# outputs = colmap_dir
# sfm_pairs = outputs / "pairs-netvlad.txt"
# sfm_dir = outputs / "sparse" / "0"
# features = outputs / "features.h5"
# matches = outputs / "matches.h5"

# retrieval_conf = extract_features.confs["netvlad"]
# feature_conf = extract_features.confs[feature_type]
# matcher_conf = match_features.confs[matcher_type]

# references = [p.relative_to(image_dir).as_posix() for p in image_dir.iterdir()]
# extract_features.main(feature_conf, image_dir, image_list=references, feature_path=features)
# if matching_method == "exhaustive":
#     pairs_from_exhaustive.main(sfm_pairs, image_list=references)
# else:
#     retrieval_path = extract_features.main(retrieval_conf, image_dir, outputs)
#     if num_matched >= len(references):
#         num_matched = len(references)
#     pairs_from_retrieval.main(retrieval_path, sfm_pairs, num_matched=num_matched)
# match_features.main(matcher_conf, sfm_pairs, features=features, matches=matches)

# skip_geometric_verification = False
# min_match_score = None
# mapper_options = None

# camera_params = np.array(
#     [newcameramtx[0,0], newcameramtx[1,1], newcameramtx[0, 2], newcameramtx[1, 2]])
# camera_params *= pose_resize_scale / upsample_factor
# image_options = pycolmap.ImageReaderOptions(  # pylint: disable=c-extension-no-member
#     camera_model=camera_model.value,
#     camera_params=camera_params
# )

# mapper_options = {
#   "ba_refine_focal_length": False,
#   "ba_refine_principal_point": False,
#   "ba_refine_extra_params": False,
# }

# sfm_dir.mkdir(parents=True, exist_ok=True)
# database = sfm_dir / 'database.db'

# reconstruction.create_empty_db(database)
# reconstruction.import_images(
#     image_dir, database, pycolmap.CameraMode.SINGLE, references, image_options)
# image_ids = reconstruction.get_image_ids(database)
# reconstruction.import_features(image_ids, database, features)
# reconstruction.import_matches(image_ids, database, sfm_pairs, matches,
#                min_match_score, skip_geometric_verification)
# if not skip_geometric_verification:
#     reconstruction.estimation_and_geometric_verification(database, sfm_pairs, verbose)
# rec_out = run_reconstruction(
#     sfm_dir, database, image_dir, verbose, mapper_options)
# if rec_out is not None:
#     logger.info(f'Reconstruction statistics:\n{rec_out.summary()}'
#                 + f'\n\tnum_input_images = {len(image_ids)}')

# %%
colmap_dir = root_dir / "reconstructions" / "r_pose"
if colmap_dir.exists():
    shutil.rmtree(colmap_dir)
os.makedirs(colmap_dir)

camera_params = np.array(
    [newcameramtx[0,0], newcameramtx[1,1], newcameramtx[0, 2], newcameramtx[1, 2]])
camera_params *= pose_resize_scale / upsample_factor

camera_model = CameraModel.PINHOLE
# run_colmap(
#     image_dir=pose_output_dir,
#     colmap_dir=colmap_dir,
#     camera_model=camera_model,
#     camera_params=camera_params,
#     gpu=True,
#     verbose=True,
#     matching_method="exhaustive"
# ); appendix = '_colmap'

run_hloc(
    image_dir=pose_output_dir,
    colmap_dir=colmap_dir,
    camera_model=camera_model,
    camera_params=camera_params,
    verbose=True,
    matching_method="exhaustive",
    feature_type="superpoint_inloc",
    matcher_type="superglue",
); appendix = '_supergloo'
# Out:
# [2023/03/14 04:04:20 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 4096, 'name': 'superpoint', 'nms_radius': 4},
#  'output': 'feats-superpoint-n4096-r1600',
#  'preprocessing': {'grayscale': True, 'resize_max': 1600}}
# Loaded SuperPoint model
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 187/187 [00:17<00:00, 10.98it/s]
# [2023/03/14 04:04:37 hloc INFO] Finished exporting features.
# [2023/03/14 04:04:37 hloc INFO] Found 17391 pairs.
# [2023/03/14 04:04:37 hloc INFO] Matching local features with configuration:
# {'model': {'name': 'superglue',
#            'sinkhorn_iterations': 50,
#            'weights': 'outdoor'},
#  'output': 'matches-superglue'}
# Loaded SuperGlue model ("outdoor" weights)
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17391/17391 [07:30<00:00, 38.58it/s]
# [2023/03/14 04:12:08 hloc INFO] Finished exporting matches.
# [2023/03/14 04:12:08 hloc INFO] Creating an empty database...
# [2023/03/14 04:12:08 hloc INFO] Importing images into the database...
# [2023/03/14 04:12:24 hloc INFO] Importing features into the database...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 187/187 [00:00<00:00, 2450.42it/s]
# [2023/03/14 04:12:25 hloc INFO] Importing matches into the database...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17391/17391 [00:09<00:00, 1837.25it/s]
# [2023/03/14 04:12:36 hloc INFO] Performing geometric verification of the matches...
# ==============================================================================
# Custom feature matching
# ==============================================================================
#
# Matching block [1/15] in 3.167s
# Matching block [2/15] in 2.919s
# Matching block [3/15] in 3.604s
# Matching block [4/15] in 3.187s
# Matching block [5/15] in 4.558s
# Matching block [6/15] in 3.551s
# Matching block [7/15] in 4.319s
# Matching block [8/15] in 3.775s
# Matching block [9/15] in 4.216s
# Matching block [10/15] in 2.782s
# Matching block [11/15] in 3.083s
# Matching block [12/15] in 4.125s
# Matching block [13/15] in 3.775s
# Matching block [14/15] in 3.418s
# Matching block [15/15] in 1.510s
# Elapsed time: 0.874 [minutes]
# [2023/03/14 04:13:29 hloc INFO] Running 3D reconstruction...
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 1 in 0.000s
# Loading matches... 7662 in 0.013s
# Loading images... 187 in 0.004s (connected 187)
# Building correspondence graph... in 0.061s (ignored 0)
#
# Elapsed time: 0.001 [minutes]
#
#
# ==============================================================================
# Finding good initial image pair
# ==============================================================================
#
#
# ==============================================================================
# Initializing with image pair #137 and #119
# ==============================================================================
#
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  6.819679e+02    0.00e+00    2.67e+04   0.00e+00   0.00e+00  1.00e+04        0    6.62e-04    1.74e-03
#    1  6.267187e+02    5.52e+01    3.30e+03   7.72e-02   1.00e+00  3.00e+04        1    1.07e-03    3.08e-03
#    2  6.262331e+02    4.86e-01    8.05e+02   4.23e-02   9.95e-01  9.00e+04        1    9.28e-04    4.30e-03
#    3  6.262184e+02    1.47e-02    2.72e+01   7.87e-03   9.99e-01  2.70e+05        1    9.32e-04    5.52e-03
#    4  6.262184e+02    5.62e-05    7.15e-01   5.01e-04   1.01e+00  8.10e+05        1    9.44e-04    6.75e-03
#    5  6.262184e+02    4.92e-08    8.90e-03   1.18e-05   1.02e+00  2.43e+06        1    9.42e-04    7.98e-03
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2128
#    Parameters : 1601
#    Iterations : 6
#          Time : 0.00831604 [s]
#  Initial cost : 0.566104 [px]
#    Final cost : 0.542472 [px]
#   Termination : Convergence
#
#   => Filtered observations: 0
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #181 (3)
# ==============================================================================
#
#   => Image sees 443 / 1367 points
#
# Pose refinement report
# ----------------------
#     Residuals : 776
#    Parameters : 6
#    Iterations : 15
#          Time : 0.00621605 [s]
#  Initial cost : 0.79342 [px]
#    Final cost : 0.780272 [px]
#   Termination : Convergence
#
#   => Continued observations: 387
#   => Added observations: 934
#
# Bundle adjustment report
# ------------------------
#     Residuals : 4770
#    Parameters : 2885
#    Iterations : 26
#          Time : 0.0669692 [s]
#  Initial cost : 0.807084 [px]
#    Final cost : 0.733373 [px]
#   Termination : No convergence
#
#   => Merged observations: 0
#   => Completed observations: 0
#   => Filtered observations: 198
#   => Changed observations: 0.083019
#
# Bundle adjustment report
# ------------------------
#     Residuals : 4374
#    Parameters : 2807
#    Iterations : 4
#          Time : 0.010108 [s]
#  Initial cost : 0.661559 [px]
#    Final cost : 0.61252 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 49
#   => Filtered observations: 0
#   => Changed observations: 0.022405
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.778237e+03    0.00e+00    3.12e+03   0.00e+00   0.00e+00  1.00e+04        0    1.71e-03    3.19e-03
#    1  1.755500e+03    2.27e+01    1.44e+01   5.83e-02   1.00e+00  3.00e+04        1    2.48e-03    6.00e-03
#    2  1.755491e+03    8.69e-03    1.74e+00   3.68e-02   9.99e-01  9.00e+04        1    2.37e-03    8.62e-03
#    3  1.755491e+03    2.14e-04    5.03e-01   8.26e-03   9.95e-01  2.70e+05        1    2.40e-03    1.13e-02
#    4  1.755491e+03    9.69e-07    1.12e-02   5.77e-04   1.00e+00  8.10e+05        1    2.38e-03    1.40e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 4472
#    Parameters : 2879
#    Iterations : 5
#          Time : 0.0143239 [s]
#  Initial cost : 0.630585 [px]
#    Final cost : 0.626539 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #176 (4)
# ==============================================================================
#
#   => Image sees 744 / 1334 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1468
#    Parameters : 6
#    Iterations : 10
#          Time : 0.00819302 [s]
#  Initial cost : 0.713916 [px]
#    Final cost : 0.707377 [px]
#   Termination : Convergence
#
#   => Continued observations: 702
#   => Added observations: 725
#
# Bundle adjustment report
# ------------------------
#     Residuals : 7326
#    Parameters : 3860
#    Iterations : 23
#          Time : 0.0951509 [s]
#  Initial cost : 0.739642 [px]
#    Final cost : 0.685257 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 7
#   => Filtered observations: 252
#   => Changed observations: 0.070707
#
# Bundle adjustment report
# ------------------------
#     Residuals : 6836
#    Parameters : 3779
#    Iterations : 3
#          Time : 0.0125151 [s]
#  Initial cost : 0.691618 [px]
#    Final cost : 0.643383 [px]
#   Termination : Convergence
#
#   => Merged observations: 4
#   => Completed observations: 50
#   => Filtered observations: 0
#   => Changed observations: 0.015799
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 6
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.943936e+03    0.00e+00    1.72e+03   0.00e+00   0.00e+00  1.00e+04        0    3.00e-03    5.75e-03
#    1  2.914691e+03    2.92e+01    3.98e+00   6.37e-02   1.00e+00  3.00e+04        1    4.49e-03    1.09e-02
#    2  2.914689e+03    2.11e-03    9.58e-01   1.76e-02   9.95e-01  9.00e+04        1    4.05e-03    1.52e-02
#    3  2.914689e+03    3.58e-05    3.54e-01   2.97e-03   9.93e-01  2.70e+05        1    4.06e-03    1.96e-02
#    4  2.914689e+03    8.77e-08    4.20e-03   1.45e-04   1.00e+00  8.10e+05        1    3.88e-03    2.38e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 6948
#    Parameters : 3833
#    Iterations : 5
#          Time : 0.0242131 [s]
#  Initial cost : 0.65093 [px]
#    Final cost : 0.647688 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #154 (5)
# ==============================================================================
#
#   => Image sees 875 / 1459 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1722
#    Parameters : 6
#    Iterations : 9
#          Time : 0.00846291 [s]
#  Initial cost : 0.737816 [px]
#    Final cost : 0.73576 [px]
#   Termination : Convergence
#
#   => Continued observations: 820
#   => Added observations: 675
#
# Bundle adjustment report
# ------------------------
#     Residuals : 9938
#    Parameters : 4739
#    Iterations : 23
#          Time : 0.136402 [s]
#  Initial cost : 0.759437 [px]
#    Final cost : 0.686214 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 20
#   => Filtered observations: 292
#   => Changed observations: 0.062789
#
# Bundle adjustment report
# ------------------------
#     Residuals : 9394
#    Parameters : 4664
#    Iterations : 3
#          Time : 0.018003 [s]
#  Initial cost : 0.716407 [px]
#    Final cost : 0.67774 [px]
#   Termination : Convergence
#
#   => Merged observations: 4
#   => Completed observations: 59
#   => Filtered observations: 1
#   => Changed observations: 0.013626
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 5
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  4.458171e+03    0.00e+00    2.06e+03   0.00e+00   0.00e+00  1.00e+04        0    3.78e-03    6.58e-03
#    1  4.410818e+03    4.74e+01    6.58e+00   1.74e-01   1.00e+00  3.00e+04        1    5.71e-03    1.26e-02
#    2  4.410816e+03    1.29e-03    1.72e+00   1.72e-02   9.95e-01  9.00e+04        1    5.46e-03    1.84e-02
#    3  4.410816e+03    2.15e-05    2.88e-01   2.89e-03   9.92e-01  2.70e+05        1    5.45e-03    2.43e-02
#    4  4.410816e+03    6.57e-08    8.65e-03   1.58e-04   9.98e-01  8.10e+05        1    5.43e-03    3.00e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 9520
#    Parameters : 4721
#    Iterations : 5
#          Time : 0.0304239 [s]
#  Initial cost : 0.684321 [px]
#    Final cost : 0.680677 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000210
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #175 (6)
# ==============================================================================
#
#   => Image sees 1008 / 1359 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2104
#    Parameters : 6
#    Iterations : 12
#          Time : 0.0134931 [s]
#  Initial cost : 0.768836 [px]
#    Final cost : 0.713279 [px]
#   Termination : Convergence
#
#   => Continued observations: 964
#   => Added observations: 539
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12528
#    Parameters : 5423
#    Iterations : 26
#          Time : 0.201242 [s]
#  Initial cost : 0.723537 [px]
#    Final cost : 0.674221 [px]
#   Termination : No convergence
#
#   => Merged observations: 12
#   => Completed observations: 22
#   => Filtered observations: 340
#   => Changed observations: 0.059706
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11892
#    Parameters : 5306
#    Iterations : 4
#          Time : 0.0305901 [s]
#  Initial cost : 0.732481 [px]
#    Final cost : 0.699108 [px]
#   Termination : Convergence
#
#   => Merged observations: 6
#   => Completed observations: 67
#   => Filtered observations: 1
#   => Changed observations: 0.012445
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 20
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  6.034926e+03    0.00e+00    2.07e+03   0.00e+00   0.00e+00  1.00e+04        0    4.96e-03    8.76e-03
#    1  5.982205e+03    5.27e+01    7.88e+00   1.87e-01   1.00e+00  3.00e+04        1    7.54e-03    1.67e-02
#    2  5.982202e+03    3.08e-03    1.93e+00   1.43e-02   1.00e+00  9.00e+04        1    7.18e-03    2.43e-02
#    3  5.982202e+03    1.79e-05    1.81e-01   2.07e-03   9.96e-01  2.70e+05        1    7.26e-03    3.19e-02
#    4  5.982202e+03    3.78e-08    3.02e-03   1.04e-04   9.97e-01  8.10e+05        1    7.17e-03    3.96e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12064
#    Parameters : 5378
#    Iterations : 5
#          Time : 0.040113 [s]
#  Initial cost : 0.707278 [px]
#    Final cost : 0.704182 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000166
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #149 (7)
# ==============================================================================
#
#   => Image sees 924 / 1351 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2000
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0139191 [s]
#  Initial cost : 0.792426 [px]
#    Final cost : 0.755884 [px]
#   Termination : Convergence
#
#   => Continued observations: 875
#   => Added observations: 485
#
# Bundle adjustment report
# ------------------------
#     Residuals : 13220
#    Parameters : 4607
#    Iterations : 26
#          Time : 0.203558 [s]
#  Initial cost : 0.752565 [px]
#    Final cost : 0.716355 [px]
#   Termination : No convergence
#
#   => Merged observations: 4
#   => Completed observations: 21
#   => Filtered observations: 401
#   => Changed observations: 0.061472
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12460
#    Parameters : 4466
#    Iterations : 3
#          Time : 0.023217 [s]
#  Initial cost : 0.771136 [px]
#    Final cost : 0.743073 [px]
#   Termination : Convergence
#
#   => Merged observations: 6
#   => Completed observations: 72
#   => Filtered observations: 1
#   => Changed observations: 0.012061
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 22
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  7.457237e+03    0.00e+00    3.76e+03   0.00e+00   0.00e+00  1.00e+04        0    5.95e-03    1.05e-02
#    1  7.375131e+03    8.21e+01    2.28e+01   2.51e-01   1.00e+00  3.00e+04        1    9.27e-03    2.02e-02
#    2  7.375112e+03    1.89e-02    1.97e+00   5.65e-02   9.94e-01  9.00e+04        1    8.85e-03    2.94e-02
#    3  7.375111e+03    4.04e-04    5.27e-01   9.26e-03   9.94e-01  2.70e+05        1    8.82e-03    3.85e-02
#    4  7.375111e+03    1.22e-06    1.28e-02   5.06e-04   9.98e-01  8.10e+05        1    8.88e-03    4.77e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 14212
#    Parameters : 5921
#    Iterations : 5
#          Time : 0.0481369 [s]
#  Initial cost : 0.724372 [px]
#    Final cost : 0.720372 [px]
#   Termination : Convergence
#
#   => Completed observations: 2
#   => Merged observations: 5
#   => Filtered observations: 4
#   => Changed observations: 0.001548
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  7.369906e+03    0.00e+00    2.22e+03   0.00e+00   0.00e+00  1.00e+04        0    5.84e-03    1.01e-02
#    1  7.358177e+03    1.17e+01    5.80e+00   3.52e-01   9.99e-01  3.00e+04        1    9.14e-03    1.97e-02
#    2  7.358169e+03    7.28e-03    7.82e-01   1.71e-02   1.00e+00  9.00e+04        1    8.86e-03    2.88e-02
#    3  7.358169e+03    1.62e-06    2.11e-02   4.23e-04   9.99e-01  2.70e+05        1    8.78e-03    3.80e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 14208
#    Parameters : 5915
#    Iterations : 4
#          Time : 0.038419 [s]
#  Initial cost : 0.720219 [px]
#    Final cost : 0.719645 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #182 (8)
# ==============================================================================
#
#   => Image sees 971 / 1247 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2190
#    Parameters : 6
#    Iterations : 10
#          Time : 0.011718 [s]
#  Initial cost : 0.737075 [px]
#    Final cost : 0.725387 [px]
#   Termination : Convergence
#
#   => Continued observations: 928
#   => Added observations: 427
#
# Bundle adjustment report
# ------------------------
#     Residuals : 14894
#    Parameters : 4733
#    Iterations : 26
#          Time : 0.216691 [s]
#  Initial cost : 0.713616 [px]
#    Final cost : 0.682408 [px]
#   Termination : No convergence
#
#   => Merged observations: 47
#   => Completed observations: 17
#   => Filtered observations: 288
#   => Changed observations: 0.046463
#
# Bundle adjustment report
# ------------------------
#     Residuals : 14358
#    Parameters : 4634
#    Iterations : 3
#          Time : 0.025352 [s]
#  Initial cost : 0.784477 [px]
#    Final cost : 0.759521 [px]
#   Termination : Convergence
#
#   => Merged observations: 5
#   => Completed observations: 54
#   => Filtered observations: 6
#   => Changed observations: 0.008896
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 22
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  9.122107e+03    0.00e+00    3.80e+03   0.00e+00   0.00e+00  1.00e+04        0    7.14e-03    1.23e-02
#    1  9.029692e+03    9.24e+01    2.02e+01   4.72e-01   1.00e+00  3.00e+04        1    1.13e-02    2.41e-02
#    2  9.029511e+03    1.80e-01    8.53e+00   1.71e-01   9.94e-01  9.00e+04        1    1.08e-02    3.52e-02
#    3  9.029507e+03    4.44e-03    1.92e+00   2.93e-02   9.95e-01  2.70e+05        1    1.08e-02    4.64e-02
#    4  9.029507e+03    1.37e-05    5.52e-02   1.63e-03   9.98e-01  8.10e+05        1    1.08e-02    5.77e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16516
#    Parameters : 6401
#    Iterations : 5
#          Time : 0.0582879 [s]
#  Initial cost : 0.743182 [px]
#    Final cost : 0.7394 [px]
#   Termination : Convergence
#
#   => Completed observations: 2
#   => Merged observations: 0
#   => Filtered observations: 1
#   => Changed observations: 0.000363
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #128 (9)
# ==============================================================================
#
#   => Image sees 950 / 1176 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2374
#    Parameters : 6
#    Iterations : 12
#          Time : 0.0155041 [s]
#  Initial cost : 0.763844 [px]
#    Final cost : 0.741285 [px]
#   Termination : Convergence
#
#   => Continued observations: 930
#   => Added observations: 467
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16244
#    Parameters : 4403
#    Iterations : 26
#          Time : 0.223856 [s]
#  Initial cost : 0.711152 [px]
#    Final cost : 0.689389 [px]
#   Termination : No convergence
#
#   => Merged observations: 31
#   => Completed observations: 17
#   => Filtered observations: 373
#   => Changed observations: 0.050644
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15530
#    Parameters : 4256
#    Iterations : 3
#          Time : 0.0261371 [s]
#  Initial cost : 0.7936 [px]
#    Final cost : 0.772907 [px]
#   Termination : Convergence
#
#   => Merged observations: 25
#   => Completed observations: 53
#   => Filtered observations: 2
#   => Changed observations: 0.010008
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 38
#   => Merged observations: 0
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.073230e+04    0.00e+00    3.67e+03   0.00e+00   0.00e+00  1.00e+04        0    8.14e-03    1.45e-02
#    1  1.062202e+04    1.10e+02    3.43e+01   2.28e-01   1.00e+00  3.00e+04        1    1.33e-02    2.81e-02
#    2  1.062200e+04    2.12e-02    1.71e+00   4.95e-02   9.98e-01  9.00e+04        1    1.27e-02    4.13e-02
#    3  1.062200e+04    3.65e-04    4.44e-01   8.14e-03   9.95e-01  2.70e+05        1    1.26e-02    5.42e-02
#    4  1.062200e+04    1.06e-06    1.03e-02   4.39e-04   9.98e-01  8.10e+05        1    1.26e-02    6.72e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18778
#    Parameters : 6896
#    Iterations : 5
#          Time : 0.067754 [s]
#  Initial cost : 0.756 [px]
#    Final cost : 0.752105 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000107
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #147 (10)
# ==============================================================================
#
#   => Image sees 952 / 1209 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2258
#    Parameters : 6
#    Iterations : 12
#          Time : 0.0147028 [s]
#  Initial cost : 0.838559 [px]
#    Final cost : 0.747454 [px]
#   Termination : Convergence
#
#   => Continued observations: 911
#   => Added observations: 529
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16394
#    Parameters : 3911
#    Iterations : 26
#          Time : 0.213752 [s]
#  Initial cost : 0.742172 [px]
#    Final cost : 0.713966 [px]
#   Termination : No convergence
#
#   => Merged observations: 29
#   => Completed observations: 18
#   => Filtered observations: 356
#   => Changed observations: 0.046068
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15124
#    Parameters : 4064
#    Iterations : 3
#          Time : 0.0238891 [s]
#  Initial cost : 0.819431 [px]
#    Final cost : 0.799552 [px]
#   Termination : Convergence
#
#   => Merged observations: 21
#   => Completed observations: 69
#   => Filtered observations: 3
#   => Changed observations: 0.011292
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 31
#   => Merged observations: 9
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.246357e+04    0.00e+00    6.24e+03   0.00e+00   0.00e+00  1.00e+04        0    9.24e-03    1.65e-02
#    1  1.234276e+04    1.21e+02    2.09e+01   3.45e-01   1.00e+00  3.00e+04        1    1.57e-02    3.26e-02
#    2  1.234271e+04    5.41e-02    2.05e+00   8.46e-02   9.96e-01  9.00e+04        1    1.47e-02    4.77e-02
#    3  1.234271e+04    9.81e-04    1.26e+00   1.22e-02   9.97e-01  2.70e+05        1    1.46e-02    6.27e-02
#    4  1.234271e+04    2.33e-06    1.69e-02   5.86e-04   1.00e+00  8.10e+05        1    1.45e-02    7.76e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 21178
#    Parameters : 7448
#    Iterations : 5
#          Time : 0.078135 [s]
#  Initial cost : 0.767147 [px]
#    Final cost : 0.763419 [px]
#   Termination : Convergence
#
#   => Completed observations: 4
#   => Merged observations: 9
#   => Filtered observations: 1
#   => Changed observations: 0.001322
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.238147e+04    0.00e+00    8.99e+02   0.00e+00   0.00e+00  1.00e+04        0    9.17e-03    1.58e-02
#    1  1.237406e+04    7.41e+00    1.93e+00   2.37e-02   1.00e+00  3.00e+04        1    1.49e-02    3.11e-02
#    2  1.237406e+04    2.16e-04    1.30e+00   4.35e-03   9.99e-01  9.00e+04        1    1.46e-02    4.60e-02
#    3  1.237406e+04    3.62e-06    5.01e-02   7.23e-04   9.97e-01  2.70e+05        1    1.57e-02    6.20e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 21184
#    Parameters : 7445
#    Iterations : 4
#          Time : 0.062973 [s]
#  Initial cost : 0.764508 [px]
#    Final cost : 0.764279 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 2
#   => Changed observations: 0.000189
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #152 (11)
# ==============================================================================
#
#   => Image sees 862 / 1079 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2038
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0144401 [s]
#  Initial cost : 0.821155 [px]
#    Final cost : 0.803055 [px]
#   Termination : Convergence
#
#   => Continued observations: 795
#   => Added observations: 415
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16158
#    Parameters : 3590
#    Iterations : 26
#          Time : 0.208638 [s]
#  Initial cost : 0.783019 [px]
#    Final cost : 0.749749 [px]
#   Termination : No convergence
#
#   => Merged observations: 8
#   => Completed observations: 20
#   => Filtered observations: 418
#   => Changed observations: 0.052231
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15158
#    Parameters : 3539
#    Iterations : 3
#          Time : 0.0234511 [s]
#  Initial cost : 0.846174 [px]
#    Final cost : 0.822307 [px]
#   Termination : Convergence
#
#   => Merged observations: 53
#   => Completed observations: 80
#   => Filtered observations: 0
#   => Changed observations: 0.016287
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 32
#   => Merged observations: 15
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.419264e+04    0.00e+00    7.86e+03   0.00e+00   0.00e+00  1.00e+04        0    1.02e-02    1.79e-02
#    1  1.406685e+04    1.26e+02    2.77e+01   2.28e-01   1.00e+00  3.00e+04        1    1.72e-02    3.57e-02
#    2  1.406683e+04    1.15e-02    1.84e+00   1.21e-02   1.00e+00  9.00e+04        1    1.65e-02    5.26e-02
#    3  1.406683e+04    5.64e-05    1.13e-01   2.25e-03   1.00e+00  2.70e+05        1    1.63e-02    6.93e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 23028
#    Parameters : 7841
#    Iterations : 4
#          Time : 0.0699489 [s]
#  Initial cost : 0.785061 [px]
#    Final cost : 0.781574 [px]
#   Termination : Convergence
#
#   => Completed observations: 3
#   => Merged observations: 0
#   => Filtered observations: 3
#   => Changed observations: 0.000521
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.406254e+04    0.00e+00    9.22e+02   0.00e+00   0.00e+00  1.00e+04        0    1.02e-02    1.70e-02
#    1  1.405413e+04    8.41e+00    1.93e+00   4.60e-02   1.00e+00  3.00e+04        1    1.69e-02    3.43e-02
#    2  1.405413e+04    1.07e-03    1.26e+00   1.47e-02   9.99e-01  9.00e+04        1    1.63e-02    5.11e-02
#    3  1.405413e+04    1.57e-05    8.85e-02   1.99e-03   9.98e-01  2.70e+05        1    1.63e-02    6.77e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 23028
#    Parameters : 7841
#    Iterations : 4
#          Time : 0.068485 [s]
#  Initial cost : 0.781455 [px]
#    Final cost : 0.781221 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 2
#   => Changed observations: 0.000174
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #124 (12)
# ==============================================================================
#
#   => Image sees 958 / 1283 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2200
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0155981 [s]
#  Initial cost : 0.811545 [px]
#    Final cost : 0.782214 [px]
#   Termination : Convergence
#
#   => Continued observations: 895
#   => Added observations: 486
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16662
#    Parameters : 3881
#    Iterations : 26
#          Time : 0.213066 [s]
#  Initial cost : 0.774407 [px]
#    Final cost : 0.743187 [px]
#   Termination : No convergence
#
#   => Merged observations: 42
#   => Completed observations: 23
#   => Filtered observations: 381
#   => Changed observations: 0.048850
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15950
#    Parameters : 3767
#    Iterations : 3
#          Time : 0.0246391 [s]
#  Initial cost : 0.850096 [px]
#    Final cost : 0.826984 [px]
#   Termination : Convergence
#
#   => Merged observations: 32
#   => Completed observations: 52
#   => Filtered observations: 3
#   => Changed observations: 0.010060
#
# ==============================================================================
# Registering image #180 (13)
# ==============================================================================
#
#   => Image sees 859 / 1059 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1862
#    Parameters : 6
#    Iterations : 17
#          Time : 0.0172541 [s]
#  Initial cost : 0.807082 [px]
#    Final cost : 0.753909 [px]
#   Termination : Convergence
#
#   => Continued observations: 804
#   => Added observations: 352
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16246
#    Parameters : 3257
#    Iterations : 26
#          Time : 0.203566 [s]
#  Initial cost : 0.766127 [px]
#    Final cost : 0.726336 [px]
#   Termination : No convergence
#
#   => Merged observations: 12
#   => Completed observations: 15
#   => Filtered observations: 308
#   => Changed observations: 0.037235
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15668
#    Parameters : 3167
#    Iterations : 3
#          Time : 0.023562 [s]
#  Initial cost : 0.847282 [px]
#    Final cost : 0.829381 [px]
#   Termination : Convergence
#
#   => Merged observations: 9
#   => Completed observations: 58
#   => Filtered observations: 2
#   => Changed observations: 0.007925
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 32
#   => Merged observations: 15
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.745598e+04    0.00e+00    3.93e+03   0.00e+00   0.00e+00  1.00e+04        0    1.20e-02    2.12e-02
#    1  1.729589e+04    1.60e+02    7.08e+00   2.88e-01   1.00e+00  3.00e+04        1    2.09e-02    4.26e-02
#    2  1.729588e+04    4.76e-03    1.90e+00   1.52e-02   1.00e+00  9.00e+04        1    2.01e-02    6.31e-02
#    3  1.729588e+04    1.04e-05    2.06e-01   9.34e-04   1.02e+00  2.70e+05        1    1.96e-02    8.32e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27070
#    Parameters : 8699
#    Iterations : 4
#          Time : 0.0838568 [s]
#  Initial cost : 0.803023 [px]
#    Final cost : 0.799332 [px]
#   Termination : Convergence
#
#   => Completed observations: 3
#   => Merged observations: 11
#   => Filtered observations: 0
#   => Changed observations: 0.001034
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.733903e+04    0.00e+00    1.02e+03   0.00e+00   0.00e+00  1.00e+04        0    1.23e-02    2.04e-02
#    1  1.733410e+04    4.93e+00    2.46e+00   1.92e-02   1.00e+00  3.00e+04        1    2.09e-02    4.17e-02
#    2  1.733410e+04    2.21e-04    1.17e+00   3.74e-03   1.02e+00  9.00e+04        1    1.91e-02    6.13e-02
#    3  1.733410e+04    1.78e-06    1.88e-01   4.34e-04   1.03e+00  2.70e+05        1    1.89e-02    8.05e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27076
#    Parameters : 8696
#    Iterations : 4
#          Time : 0.0811238 [s]
#  Initial cost : 0.80024 [px]
#    Final cost : 0.800126 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #129 (14)
# ==============================================================================
#
#   => Image sees 793 / 1046 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2062
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0143368 [s]
#  Initial cost : 0.822265 [px]
#    Final cost : 0.762305 [px]
#   Termination : Convergence
#
#   => Continued observations: 764
#   => Added observations: 478
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17994
#    Parameters : 3569
#    Iterations : 19
#          Time : 0.154565 [s]
#  Initial cost : 0.747475 [px]
#    Final cost : 0.724636 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 16
#   => Filtered observations: 310
#   => Changed observations: 0.033463
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17404
#    Parameters : 3455
#    Iterations : 3
#          Time : 0.024544 [s]
#  Initial cost : 0.855642 [px]
#    Final cost : 0.840592 [px]
#   Termination : Convergence
#
#   => Merged observations: 10
#   => Completed observations: 39
#   => Filtered observations: 2
#   => Changed observations: 0.005399
#
# ==============================================================================
# Registering image #184 (15)
# ==============================================================================
#
#   => Image sees 952 / 1126 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2728
#    Parameters : 6
#    Iterations : 10
#          Time : 0.0147779 [s]
#  Initial cost : 0.781702 [px]
#    Final cost : 0.76448 [px]
#   Termination : Convergence
#
#   => Continued observations: 924
#   => Added observations: 417
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19892
#    Parameters : 3764
#    Iterations : 21
#          Time : 0.187387 [s]
#  Initial cost : 0.737132 [px]
#    Final cost : 0.715969 [px]
#   Termination : Convergence
#
#   => Merged observations: 20
#   => Completed observations: 15
#   => Filtered observations: 370
#   => Changed observations: 0.038924
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19232
#    Parameters : 3608
#    Iterations : 3
#          Time : 0.026814 [s]
#  Initial cost : 0.848588 [px]
#    Final cost : 0.831902 [px]
#   Termination : Convergence
#
#   => Merged observations: 35
#   => Completed observations: 46
#   => Filtered observations: 0
#   => Changed observations: 0.008051
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 98
#   => Merged observations: 6
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.081986e+04    0.00e+00    7.19e+03   0.00e+00   0.00e+00  1.00e+04        0    1.39e-02    2.31e-02
#    1  2.064488e+04    1.75e+02    1.27e+02   7.75e-01   1.00e+00  3.00e+04        1    2.42e-02    4.77e-02
#    2  2.064470e+04    1.79e-01    4.38e+00   1.50e-01   9.96e-01  9.00e+04        1    2.26e-02    7.07e-02
#    3  2.064470e+04    2.12e-03    1.79e+00   1.72e-02   1.00e+00  2.70e+05        1    2.32e-02    9.43e-02
#    4  2.064470e+04    4.36e-06    2.45e-01   7.33e-04   1.02e+00  8.10e+05        1    2.25e-02    1.17e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31304
#    Parameters : 9614
#    Iterations : 5
#          Time : 0.117821 [s]
#  Initial cost : 0.815528 [px]
#    Final cost : 0.81209 [px]
#   Termination : Convergence
#
#   => Completed observations: 9
#   => Merged observations: 11
#   => Filtered observations: 3
#   => Changed observations: 0.001469
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.070626e+04    0.00e+00    1.32e+03   0.00e+00   0.00e+00  1.00e+04        0    1.40e-02    2.32e-02
#    1  2.067722e+04    2.90e+01    3.29e+00   1.11e-01   1.00e+00  3.00e+04        1    2.39e-02    4.75e-02
#    2  2.067722e+04    2.44e-03    1.92e+00   1.52e-02   9.98e-01  9.00e+04        1    2.27e-02    7.07e-02
#    3  2.067722e+04    3.06e-05    2.70e-01   1.88e-03   1.00e+00  2.70e+05        1    2.38e-02    9.49e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31316
#    Parameters : 9611
#    Iterations : 4
#          Time : 0.0955489 [s]
#  Initial cost : 0.813144 [px]
#    Final cost : 0.812574 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 3
#   => Changed observations: 0.000255
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #155 (16)
# ==============================================================================
#
#   => Image sees 838 / 943 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2280
#    Parameters : 6
#    Iterations : 12
#          Time : 0.0147591 [s]
#  Initial cost : 0.774017 [px]
#    Final cost : 0.754539 [px]
#   Termination : Convergence
#
#   => Continued observations: 811
#   => Added observations: 324
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18942
#    Parameters : 3467
#    Iterations : 25
#          Time : 0.210371 [s]
#  Initial cost : 0.73132 [px]
#    Final cost : 0.711588 [px]
#   Termination : Convergence
#
#   => Merged observations: 33
#   => Completed observations: 6
#   => Filtered observations: 284
#   => Changed observations: 0.031754
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18432
#    Parameters : 3371
#    Iterations : 3
#          Time : 0.0255301 [s]
#  Initial cost : 0.857373 [px]
#    Final cost : 0.84477 [px]
#   Termination : Convergence
#
#   => Merged observations: 15
#   => Completed observations: 44
#   => Filtered observations: 3
#   => Changed observations: 0.006253
#
# ==============================================================================
# Registering image #187 (17)
# ==============================================================================
#
#   => Image sees 913 / 1129 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2652
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0116718 [s]
#  Initial cost : 0.751115 [px]
#    Final cost : 0.748394 [px]
#   Termination : Convergence
#
#   => Continued observations: 872
#   => Added observations: 421
#
# Bundle adjustment report
# ------------------------
#     Residuals : 20032
#    Parameters : 3443
#    Iterations : 23
#          Time : 0.206093 [s]
#  Initial cost : 0.759501 [px]
#    Final cost : 0.741437 [px]
#   Termination : Convergence
#
#   => Merged observations: 26
#   => Completed observations: 20
#   => Filtered observations: 376
#   => Changed observations: 0.039770
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19360
#    Parameters : 3293
#    Iterations : 3
#          Time : 0.0269699 [s]
#  Initial cost : 0.859578 [px]
#    Final cost : 0.845195 [px]
#   Termination : Convergence
#
#   => Merged observations: 17
#   => Completed observations: 52
#   => Filtered observations: 3
#   => Changed observations: 0.007009
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 90
#   => Merged observations: 13
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.361744e+04    0.00e+00    6.99e+03   0.00e+00   0.00e+00  1.00e+04        0    1.60e-02    2.73e-02
#    1  2.342875e+04    1.89e+02    3.62e+01   5.60e-01   1.00e+00  3.00e+04        1    2.85e-02    5.62e-02
#    2  2.342867e+04    8.44e-02    2.09e+00   9.73e-02   9.96e-01  9.00e+04        1    2.90e-02    8.56e-02
#    3  2.342867e+04    1.10e-03    1.65e+00   1.17e-02   1.00e+00  2.70e+05        1    2.76e-02    1.14e-01
#    4  2.342867e+04    2.60e-06    2.53e-01   5.26e-04   1.02e+00  8.10e+05        1    2.67e-02    1.41e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35258
#    Parameters : 10319
#    Iterations : 5
#          Time : 0.141804 [s]
#  Initial cost : 0.818441 [px]
#    Final cost : 0.815164 [px]
#   Termination : Convergence
#
#   => Completed observations: 10
#   => Merged observations: 13
#   => Filtered observations: 2
#   => Changed observations: 0.001418
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.350937e+04    0.00e+00    1.54e+03   0.00e+00   0.00e+00  1.00e+04        0    1.58e-02    2.65e-02
#    1  2.348115e+04    2.82e+01    9.60e+00   1.90e-01   1.00e+00  3.00e+04        1    2.83e-02    5.53e-02
#    2  2.348114e+04    2.83e-03    1.27e+00   6.99e-03   1.00e+00  9.00e+04        1    2.68e-02    8.25e-02
#    3  2.348114e+04    5.19e-06    1.06e-01   7.05e-04   1.00e+00  2.70e+05        1    2.73e-02    1.10e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35274
#    Parameters : 10313
#    Iterations : 4
#          Time : 0.110911 [s]
#  Initial cost : 0.816382 [px]
#    Final cost : 0.815891 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 1
#   => Changed observations: 0.000113
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #186 (18)
# ==============================================================================
#
#   => Image sees 931 / 1094 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2816
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0122318 [s]
#  Initial cost : 0.75199 [px]
#    Final cost : 0.736159 [px]
#   Termination : Convergence
#
#   => Continued observations: 906
#   => Added observations: 279
#
# Bundle adjustment report
# ------------------------
#     Residuals : 20758
#    Parameters : 3434
#    Iterations : 26
#          Time : 0.233046 [s]
#  Initial cost : 0.741762 [px]
#    Final cost : 0.728907 [px]
#   Termination : No convergence
#
#   => Merged observations: 18
#   => Completed observations: 9
#   => Filtered observations: 358
#   => Changed observations: 0.034987
#
# Bundle adjustment report
# ------------------------
#     Residuals : 20066
#    Parameters : 3287
#    Iterations : 3
#          Time : 0.0269861 [s]
#  Initial cost : 0.857063 [px]
#    Final cost : 0.842987 [px]
# ...
# ------------------------
#     Residuals : 3150
#    Parameters : 554
#    Iterations : 3
#          Time : 0.005404 [s]
#  Initial cost : 0.913346 [px]
#    Final cost : 0.900371 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 9
#   => Filtered observations: 2
#   => Changed observations: 0.005904
#
# ==============================================================================
# Registering image #80 (179)
# ==============================================================================
#
#   => Image sees 154 / 179 points
#
# Pose refinement report
# ----------------------
#     Residuals : 406
#    Parameters : 6
#    Iterations : 11
#          Time : 0.00239682 [s]
#  Initial cost : 0.828914 [px]
#    Final cost : 0.787646 [px]
#   Termination : Convergence
#
#   => Continued observations: 141
#   => Added observations: 92
#
# Bundle adjustment report
# ------------------------
#     Residuals : 3100
#    Parameters : 386
#    Iterations : 15
#          Time : 0.0232742 [s]
#  Initial cost : 0.88334 [px]
#    Final cost : 0.865746 [px]
#   Termination : Convergence
#
#   => Merged observations: 30
#   => Completed observations: 1
#   => Filtered observations: 63
#   => Changed observations: 0.043478
#
# Bundle adjustment report
# ------------------------
#     Residuals : 3150
#    Parameters : 611
#    Iterations : 3
#          Time : 0.00515509 [s]
#  Initial cost : 0.897768 [px]
#    Final cost : 0.882481 [px]
#   Termination : Convergence
#
#   => Merged observations: 15
#   => Completed observations: 7
#   => Filtered observations: 1
#   => Changed observations: 0.013241
#
# ==============================================================================
# Registering image #89 (180)
# ==============================================================================
#
#   => Image sees 147 / 172 points
#
# Pose refinement report
# ----------------------
#     Residuals : 360
#    Parameters : 6
#    Iterations : 14
#          Time : 0.00303912 [s]
#  Initial cost : 0.857577 [px]
#    Final cost : 0.795009 [px]
#   Termination : Convergence
#
#   => Continued observations: 132
#   => Added observations: 82
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2436
#    Parameters : 599
#    Iterations : 26
#          Time : 0.0336959 [s]
#  Initial cost : 0.883535 [px]
#    Final cost : 0.827723 [px]
#   Termination : No convergence
#
#   => Merged observations: 29
#   => Completed observations: 5
#   => Filtered observations: 63
#   => Changed observations: 0.070443
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2334
#    Parameters : 575
#    Iterations : 3
#          Time : 0.00410914 [s]
#  Initial cost : 0.894721 [px]
#    Final cost : 0.879365 [px]
#   Termination : Convergence
#
#   => Merged observations: 12
#   => Completed observations: 12
#   => Filtered observations: 2
#   => Changed observations: 0.019623
#
# ==============================================================================
# Registering image #73 (181)
# ==============================================================================
#
#   => Image sees 176 / 193 points
#
# Pose refinement report
# ----------------------
#     Residuals : 454
#    Parameters : 6
#    Iterations : 18
#          Time : 0.00449109 [s]
#  Initial cost : 0.855635 [px]
#    Final cost : 0.832294 [px]
#   Termination : Convergence
#
#   => Continued observations: 154
#   => Added observations: 93
#
# Bundle adjustment report
# ------------------------
#     Residuals : 5550
#    Parameters : 488
#    Iterations : 26
#          Time : 0.068398 [s]
#  Initial cost : 0.916342 [px]
#    Final cost : 0.892379 [px]
#   Termination : No convergence
#
#   => Merged observations: 0
#   => Completed observations: 8
#   => Filtered observations: 115
#   => Changed observations: 0.034785
#
# Bundle adjustment report
# ------------------------
#     Residuals : 6624
#    Parameters : 440
#    Iterations : 3
#          Time : 0.010011 [s]
#  Initial cost : 0.921049 [px]
#    Final cost : 0.911734 [px]
#   Termination : Convergence
#
#   => Merged observations: 16
#   => Completed observations: 12
#   => Filtered observations: 2
#   => Changed observations: 0.008532
#
# ==============================================================================
# Registering image #109 (182)
# ==============================================================================
#
#   => Image sees 132 / 171 points
#
# Pose refinement report
# ----------------------
#     Residuals : 166
#    Parameters : 6
#    Iterations : 15
#          Time : 0.00152397 [s]
#  Initial cost : 0.894948 [px]
#    Final cost : 0.859301 [px]
#   Termination : Convergence
#
#   => Continued observations: 74
#   => Added observations: 96
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2920
#    Parameters : 308
#    Iterations : 26
#          Time : 0.0372109 [s]
#  Initial cost : 1.06647 [px]
#    Final cost : 0.954962 [px]
#   Termination : No convergence
#
#   => Merged observations: 13
#   => Completed observations: 13
#   => Filtered observations: 123
#   => Changed observations: 0.083101
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2114
#    Parameters : 242
#    Iterations : 4
#          Time : 0.00415707 [s]
#  Initial cost : 1.0507 [px]
#    Final cost : 1.03053 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 9
#   => Filtered observations: 2
#   => Changed observations: 0.007785
#
# ==============================================================================
# Registering image #139 (183)
# ==============================================================================
#
#   => Image sees 168 / 205 points
#
# Pose refinement report
# ----------------------
#     Residuals : 412
#    Parameters : 6
#    Iterations : 15
#          Time : 0.0033381 [s]
#  Initial cost : 0.82491 [px]
#    Final cost : 0.782558 [px]
#   Termination : Convergence
#
#   => Continued observations: 145
#   => Added observations: 84
#
# Bundle adjustment report
# ------------------------
#     Residuals : 7034
#    Parameters : 569
#    Iterations : 24
#          Time : 0.0815701 [s]
#  Initial cost : 0.81236 [px]
#    Final cost : 0.794949 [px]
#   Termination : Convergence
#
#   => Merged observations: 13
#   => Completed observations: 2
#   => Filtered observations: 75
#   => Changed observations: 0.022255
#
# Bundle adjustment report
# ------------------------
#     Residuals : 6922
#    Parameters : 569
#    Iterations : 3
#          Time : 0.0104699 [s]
#  Initial cost : 0.94541 [px]
#    Final cost : 0.935464 [px]
#   Termination : Convergence
#
#   => Merged observations: 13
#   => Completed observations: 7
#   => Filtered observations: 1
#   => Changed observations: 0.005319
#
# ==============================================================================
# Registering image #81 (184)
# ==============================================================================
#
#   => Image sees 107 / 120 points
#
# Pose refinement report
# ----------------------
#     Residuals : 258
#    Parameters : 6
#    Iterations : 17
#          Time : 0.00236297 [s]
#  Initial cost : 0.900466 [px]
#    Final cost : 0.83263 [px]
#   Termination : Convergence
#
#   => Continued observations: 94
#   => Added observations: 55
#
# Bundle adjustment report
# ------------------------
#     Residuals : 3514
#    Parameters : 305
#    Iterations : 26
#          Time : 0.0447021 [s]
#  Initial cost : 0.890413 [px]
#    Final cost : 0.857359 [px]
#   Termination : No convergence
#
#   => Merged observations: 15
#   => Completed observations: 8
#   => Filtered observations: 56
#   => Changed observations: 0.039599
#
# Bundle adjustment report
# ------------------------
#     Residuals : 3432
#    Parameters : 284
#    Iterations : 3
#          Time : 0.00528407 [s]
#  Initial cost : 0.92262 [px]
#    Final cost : 0.914956 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 10
#   => Filtered observations: 0
#   => Changed observations: 0.005488
#
# ==============================================================================
# Registering image #72 (185)
# ==============================================================================
#
#   => Image sees 84 / 98 points
#
# Pose refinement report
# ----------------------
#     Residuals : 216
#    Parameters : 6
#    Iterations : 43
#          Time : 0.00494504 [s]
#  Initial cost : 0.852557 [px]
#    Final cost : 0.826424 [px]
#   Termination : Convergence
#
#   => Continued observations: 77
#   => Added observations: 29
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2960
#    Parameters : 209
#    Iterations : 18
#          Time : 0.0257831 [s]
#  Initial cost : 0.939355 [px]
#    Final cost : 0.919114 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 5
#   => Filtered observations: 53
#   => Changed observations: 0.024818
#
# Bundle adjustment report
# ------------------------
#     Residuals : 3262
#    Parameters : 218
#    Iterations : 3
#          Time : 0.00501418 [s]
#  Initial cost : 0.98439 [px]
#    Final cost : 0.975514 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 6
#   => Filtered observations: 0
#   => Changed observations: 0.003032
#
# ==============================================================================
# Registering image #82 (186)
# ==============================================================================
#
#   => Image sees 44 / 53 points
#
# Pose refinement report
# ----------------------
#     Residuals : 104
#    Parameters : 6
#    Iterations : 21
#          Time : 0.00141215 [s]
#  Initial cost : 0.841759 [px]
#    Final cost : 0.811135 [px]
#   Termination : Convergence
#
#   => Continued observations: 38
#   => Added observations: 24
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2082
#    Parameters : 176
#    Iterations : 16
#          Time : 0.0191619 [s]
#  Initial cost : 0.852164 [px]
#    Final cost : 0.830942 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 5
#   => Filtered observations: 22
#   => Changed observations: 0.019272
#
# Bundle adjustment report
# ------------------------
#     Residuals : 1790
#    Parameters : 179
#    Iterations : 3
#          Time : 0.00300312 [s]
#  Initial cost : 1.05384 [px]
#    Final cost : 1.04409 [px]
#   Termination : Convergence
#
#   => Merged observations: 11
#   => Completed observations: 4
#   => Filtered observations: 0
#   => Changed observations: 0.011655
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 111
#   => Merged observations: 0
#   => Retriangulated observations: 219
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  3.107229e+05    0.00e+00    1.60e+05   0.00e+00   0.00e+00  1.00e+04        0    2.19e-02    1.82e-01
#    1  2.341782e+05    7.65e+04    2.71e+04   3.09e+00   9.97e-01  3.00e+04        1    3.53e-01    5.36e-01
#    2  2.337840e+05    3.94e+02    4.01e+03   6.02e-01   1.02e+00  9.00e+04        1    1.76e-01    7.13e-01
#    3  2.337804e+05    3.63e+00    5.94e+02   1.70e-01   1.16e+00  2.70e+05        1    1.75e-01    8.88e-01
#    4  2.337802e+05    1.56e-01    1.24e+02   3.42e-02   1.20e+00  8.10e+05        1    1.63e-01    1.05e+00
#    5  2.337802e+05    6.83e-03    2.49e+01   7.00e-03   1.20e+00  2.43e+06        1    1.81e-01    1.23e+00
#    6  2.337802e+05    2.93e-04    5.29e+00   1.38e-03   1.21e+00  7.29e+06        1    1.75e-01    1.41e+00
#    7  2.337802e+05    1.24e-05    1.22e+00   2.88e-04   1.21e+00  2.19e+07        1    1.68e-01    1.58e+00
#    8  2.337802e+05    5.26e-07    4.20e-01   5.82e-05   1.21e+00  6.56e+07        1    1.69e-01    1.75e+00
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 222838
#    Parameters : 42452
#    Iterations : 9
#          Time : 1.75163 [s]
#  Initial cost : 1.18084 [px]
#    Final cost : 1.02426 [px]
#   Termination : Convergence
#
#   => Completed observations: 75
#   => Merged observations: 179
#   => Filtered observations: 559
#   => Changed observations: 0.007297
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.714243e+05    0.00e+00    3.99e+04   0.00e+00   0.00e+00  1.00e+04        0    2.37e-02    1.83e-01
#    1  1.677880e+05    3.64e+03    6.22e+03   9.60e-01   9.99e-01  3.00e+04        1    3.36e-01    5.19e-01
#    2  1.677765e+05    1.14e+01    1.13e+02   3.65e-01   1.01e+00  9.00e+04        1    1.58e-01    6.78e-01
#    3  1.677764e+05    1.86e-01    6.31e+00   6.52e-02   1.02e+00  2.70e+05        1    1.58e-01    8.37e-01
#    4  1.677764e+05    1.27e-03    1.59e+00   5.15e-03   1.04e+00  8.10e+05        1    1.66e-01    1.00e+00
#    5  1.677764e+05    5.47e-06    1.52e-01   2.36e-04   1.08e+00  2.43e+06        1    1.69e-01    1.17e+00
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 221868
#    Parameters : 42278
#    Iterations : 6
#          Time : 1.17706 [s]
#  Initial cost : 0.879 [px]
#    Final cost : 0.869597 [px]
#   Termination : Convergence
#
#   => Completed observations: 252
#   => Merged observations: 339
#   => Filtered observations: 35
#   => Changed observations: 0.005643
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.687481e+05    0.00e+00    1.40e+04   0.00e+00   0.00e+00  1.00e+04        0    2.21e-02    1.90e-01
#    1  1.683411e+05    4.07e+02    4.07e+01   2.29e-01   1.00e+00  3.00e+04        1    3.48e-01    5.38e-01
#    2  1.683410e+05    1.24e-01    8.51e+00   4.47e-02   1.01e+00  9.00e+04        1    1.78e-01    7.17e-01
#    3  1.683410e+05    1.61e-03    1.44e+00   4.76e-03   1.02e+00  2.70e+05        1    1.69e-01    8.87e-01
#    4  1.683410e+05    1.30e-05    1.23e-01   4.10e-04   1.02e+00  8.10e+05        1    1.69e-01    1.06e+00
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 222300
#    Parameters : 42227
#    Iterations : 5
#          Time : 1.0596 [s]
#  Initial cost : 0.871264 [px]
#    Final cost : 0.870212 [px]
#   Termination : Convergence
#
#   => Completed observations: 31
#   => Merged observations: 24
#   => Filtered observations: 7
#   => Changed observations: 0.000558
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.685157e+05    0.00e+00    4.21e+03   0.00e+00   0.00e+00  1.00e+04        0    2.20e-02    1.85e-01
#    1  1.684581e+05    5.76e+01    6.55e+00   6.26e-02   1.00e+00  3.00e+04        1    3.48e-01    5.33e-01
#    2  1.684581e+05    5.82e-03    1.90e+00   1.17e-02   1.01e+00  9.00e+04        1    1.66e-01    6.99e-01
#    3  1.684581e+05    4.40e-05    3.11e-01   1.23e-03   1.02e+00  2.70e+05        1    1.72e-01    8.72e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 222348
#    Parameters : 42221
#    Iterations : 4
#          Time : 0.875471 [s]
#  Initial cost : 0.87057 [px]
#    Final cost : 0.870421 [px]
#   Termination : Convergence
#
#   => Completed observations: 7
#   => Merged observations: 23
#   => Filtered observations: 6
#   => Changed observations: 0.000324
#   => Filtered images: 0
#
# Elapsed time: 1.516 [minutes]
# [2023/03/14 04:15:00 hloc INFO] Reconstructed 1 model(s).
# [2023/03/14 04:15:00 hloc INFO] Largest model is #0 with 186 images.
# Reconstruction statistics:
# Reconstruction:
# 	num_reg_images = 186
# 	num_cameras = 1
# 	num_points3D = 13703
# 	num_observations = 111175
# 	mean_track_length = 8.11319
# 	mean_observations_per_image = 597.715
# 	mean_reprojection_error = 1.40947
# 	num_input_images = 187

# %%
recon_dir = colmap_dir / "sparse" / "0"

cam_id_to_camera = read_cameras_binary(recon_dir / "cameras.bin")
im_id_to_image = read_images_binary(recon_dir / "images.bin")

print(f"{len(im_id_to_image)} frames matched..")

frames = []
for im_id, im_data in im_id_to_image.items():
    # NB: COLMAP uses Eigen / scalar-first quaternions
    # * https://colmap.github.io/format.html
    # * https://github.com/colmap/colmap/blob/bf3e19140f491c3042bfd85b7192ef7d249808ec/src/base/pose.cc#L75
    # the `rotation_matrix()` handles that format for us.

    # TODO(1480) BEGIN use pycolmap API
    # rotation = im_data.rotation_matrix()
    rotation = qvec2rotmat(im_data.qvec)

    translation = im_data.tvec.reshape(3, 1)
    w2c = np.concatenate([rotation, translation], 1)
    w2c = np.concatenate([w2c, np.array([[0, 0, 0, 1]])], 0)
    c2w = np.linalg.inv(w2c)
    # Convert from COLMAP's camera coordinate system (OpenCV) to ours (OpenGL)
    c2w[0:3, 1:3] *= -1
    c2w = c2w[np.array([1, 0, 2, 3]), :]
    c2w[2, :] *= -1

    name = im_data.name.split(".")[0]+".exr"
    name = Path(f"./{exr_output_dir.name}/{name}")
    
#     name = im_data.name.split(".")[0]+".png"
#     name = Path(f"./{png_output_dir.name}/{name}")

    frame = {
        "file_path": name.as_posix(),
        "transform_matrix": c2w.tolist(),
#         "colmap_im_id": im_id,
    }
    frames.append(frame)
    
# Read camera params and write frame information
transforms_json = parse_colmap_camera_params(cam_id_to_camera[1])
transforms_json["frames"] = frames

# Scale camera params
cam_params = np.array([
    transforms_json["w"], transforms_json["h"], 
    transforms_json["fl_x"], transforms_json["fl_y"], transforms_json["cx"], transforms_json["cy"]])
cam_param_scaled = cam_params / pose_resize_scale

transforms_json["w"], transforms_json["h"], \
    transforms_json["fl_x"], transforms_json["fl_y"],\
    transforms_json["cx"], transforms_json["cy"] = tuple(cam_param_scaled)

write_to_json(root_dir/("transforms%s.json"%appendix), transforms_json)
print(f"Wrote info to {root_dir/('transforms%s.json'%appendix)} file!")
# Out:
# 186 frames matched..
# Wrote info to /Data/Datasets/IndoorInverseRendering/Canon/CSEKitchen/transforms_supergloo.json file!

# %%
# from hloc.utils.database import COLMAPDatabase, array_to_blob, blob_to_array

# database_path = colmap_dir / "database.db"
# db = COLMAPDatabase.connect(database_path)

# rows = db.execute("SELECT * FROM cameras")

# camera_id, model, width, height, params, prior = next(rows)
# params = blob_to_array(params, np.float64)
